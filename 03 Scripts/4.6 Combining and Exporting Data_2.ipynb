# %% [markdown]
# # Exercise 4.6 Task

# %% [markdown]
# ## Table of Contents:

# %% [markdown]
# #### 01. Importing libraries
# #### 02. Importing Data
# #### 03. Task 4.6 Work

# %% [markdown]
# ## 01. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing Data

# %%
path = r'C:\Users\Rebecca\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\Rebecca\\Instacart Basket Analysis'

# %%
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  _merge                  category
# dtypes: category(1), float64(1), int64(8), object(1)
# memory usage: 2.4+ GB

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_cleaned.csv'), index_col = False)

# %% [markdown]
# ## 03. Task 4.6 Work

# %%
df_ords_prods_combined.shape
# Out:
# (32434489, 11)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Droping Unnamed 0 column
df_prods.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Merging ords_prods_combined with df_prods
df_ords_prods_merge = df_ords_prods_combined.merge(df_prods, on = 'product_id', how='inner', indicator = 'source')

# %%
# Checking merge
df_ords_prods_merge
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32404854   2977660   206209    prior            13                   1
# 32404855   2977660   206209    prior            13                   1
# 32404856   2977660   206209    prior            13                   1
# 32404857   2977660   206209    prior            13                   1
# 32404858   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
# Confirming results
df_ords_prods_merge['source'].value_counts()
# Out:
# source
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Exporting newly merged df as pickle
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_ords_prods_merge.pkl'))

# %%
# Exporting new df_prods_cleaned after removing rouge column
df_prods.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_cleaned.csv'))
